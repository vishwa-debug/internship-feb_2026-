# %%
# Step 1: Import pandas library
import pandas as pd

# Step 2: Load dataset
data = pd.read_csv("D:/data.csv")

# Step 3: Display first 5 rows
print("Top 5 rows of dataset:")
print(data.head())

# Step 4: Find highest value in each column
print("\nHighest value in each column:")
print(data.max())

# Step 5: Count missing values
print("\nMissing values in dataset:")
print(data.isnull().sum())

# Step 6: Basic insights
print("\nNumber of rows and columns:")
print(data.shape)

print("\nColumn names:")
print(data.columns)
# Out:
# Top 5 rows of dataset:
#    Name   Age  Marks
# 0   Ram  20.0     85
# 1  Sita  21.0     90
# 2  Ravi  19.0     78
# 3   Anu  22.0     88
# 4   Raj   NaN     75
#
# Highest value in each column:
# Name     Sita
# Age      22.0
# Marks      90
# dtype: object
#
# Missing values in dataset:
# Name     0
# Age      1
# Marks    0
# dtype: int64
#
# Number of rows and columns:
# (5, 3)
#
# Column names:
# Index(['Name', 'Age', 'Marks'], dtype='object')
